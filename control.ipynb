# %%
import pandas as pd
df = pd.read_csv("outputs/run_2026-03-11_10-23-42/logs/20/tram_001.csv")
print(df[["boarded", "alighted"]].describe())
print("Среднее boarded + alighted:", (df["boarded"] + df["alighted"]).mean())
# Out:
#          boarded   alighted
# count  92.000000  92.000000
# mean    9.195652   9.184783
# std    17.154911  10.689349
# min     0.000000   0.000000
# 25%     0.000000   0.750000
# 50%     0.000000   3.500000
# 75%    13.250000  17.250000
# max    79.000000  47.000000
# Среднее boarded + alighted: 18.380434782608695
